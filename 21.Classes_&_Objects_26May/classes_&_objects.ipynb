# %%
nums=[10,20,30] # nums is a object of list class. so it has all the properties and methods of list class. but it does not have upper() method. so it will give an error.
nums.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 nums=[10,20,30]
# ----> 2 nums.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
list1=list # list1 is a object of list class.  
list1.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 list1=list
# ----> 2 list1.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
str1="Hello World" # str1 is a object of string class.  
print(type(str1))
# Out:
# <class 'str'>

# %%
tuple1=tuple() # tuple1 is a object of tuple class.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 tuple1=tuple()
#
# TypeError: 'tuple' object is not callable

# %%
dict1=dict() # dict1 is a object of dict class.

# %%
set1=set() # set1 is a object of set class.
