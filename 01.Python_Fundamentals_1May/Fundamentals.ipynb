# %% [markdown]
# ## Python is Case Sensitive

# %%
A=10
a=20

print(A)

print(a)
# Out:
# 10
# 20

# %% [markdown]
# ## Basic datatype in Python

# %% [markdown]
# #### Basic Types:

# %%
age=25
print(type(age))
# Out:
# <class 'int'>

# %%
weight=67.5
print(type(weight))
# Out:
# <class 'float'>

# %%
num=1+2j
print(type(num))
# Out:
# <class 'complex'>

# %%
Voting=True
print(type(Voting))
# Out:
# <class 'bool'>

# %%
name="Smruti"
print(type(name))
# Out:
# <class 'str'>

# %% [markdown]
# ## Float-decimal

# %%
pi=3.14
print(type(pi))
# Out:
# <class 'float'>

# %% [markdown]
# ## Exponential

# %%
pi_exp=3.14e2
print(pi_exp)
# Out:
# 314.0

# %% [markdown]
# ## Complex Datatype

# %%
c1=1+2j
print(type(c1))
# Out:
# <class 'complex'>

# %% [markdown]
# ## Bool Datatype

# %%
is_active=True
print(type(is_active))
# Out:
# <class 'bool'>

# %%
is_deleted=False
print(type(is_deleted))
# Out:
# <class 'bool'>

# %% [markdown]
# ## String Datatype

# %%
name='Smruti'
print(type(name))
# Out:
# <class 'str'>

# %%
name="Shivani"
print(type(name))
# Out:
# <class 'str'>

# %%
name='''Suraj'''
print(type(name))
# Out:
# <class 'str'>

# %%
name= """Rajesh"""
print(type(name))
# Out:
# <class 'str'>

# %% [markdown]
# ## Variable Assignment

# %%
age=10
weight=65.5
num=1+2j
eligible_for_voting=True
name="Rajesh" \
""

# %% [markdown]
# ## Multiple variable in one line

# %%
age,weight,num,elegible_for_voting,name= 10,65.5,1+2j,True,"Smruti"
print(age,weight,num,elegible_for_voting,name)
# Out:
# 10 65.5 (1+2j) True Smruti

# %% [markdown]
# # Same Level Exponential (Left to Right)

# %%
result=10-2+3**2

result
# Out:
# 17

# %% [markdown]
# # Float to int

# %%
x=int(3.8)
print(x)
# Out:
# 3

# %% [markdown]
# # String to int

# %%
y=int("10")
print(y)
# Out:
# 10

# %% [markdown]
# # Converting to complex

# %%
complex(4.1)
# Out:
# (4.1+0j)

# %%
complex("3.5j")
# Out:
# 3.5j

# %%
complex(False)
# Out:
# 0j

# %% [markdown]
# ## Converting to Boolean-bool()

# %% [markdown]
# #### Non zero numbers: True

# %%
x=bool(1)
print(x)
# Out:
# True

# %%
y=bool(0)
print(y)
# Out:
# False

# %% [markdown]
# ## Non-empty string: True

# %%
z=bool("Hello")
print(z)
# Out:
# True

# %%
w=bool("")
print(w)
# Out:
# False

# %% [markdown]
# ## Special values

# %%
a=bool(0.0)
print(a)
# Out:
# False

# %%
b=bool(0+0j)
print(b)
# Out:
# False

# %%
c=bool("Jai Ganesh")
print(c)
# Out:
# True

# %% [markdown]
# # Conversion of Boolean to bool

# %%
bool("Hello")
# Out:
# True

# %%
bool("")
# Out:
# False

# %%
bool(10.1)
# Out:
# True

# %%
bool(0+0j)
# Out:
# False
