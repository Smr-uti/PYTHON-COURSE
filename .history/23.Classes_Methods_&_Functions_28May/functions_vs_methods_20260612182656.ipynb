# %%
list1=[10,20,30]
print(type(list1))

list1.append(40)
print(list1)
# Out:
# <class 'list'>
# [10, 20, 30, 40]

# %%
list1.insert(0,5)
print(list1)
# Out:
# [5, 10, 20, 30, 40]

# %%
len(list1)
print(len(list1))
# Out:
# 5
