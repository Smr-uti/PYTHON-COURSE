# %% [markdown]
# # String:--
# #### Collection of unicode characters

# %%
name="Rajesh"

print(name)

print(type(name))
# Out:
# Rajesh
# <class 'str'>

# %%
name1='Ramesh'

print(name1)

print(type(name1))
# Out:
# Rajesh
# <class 'str'>

# %%
name2='''Mahesh'''

print(name2)
# Out:
# Mahesh

# %%
name3="""Suresh"""

print(name3)

print(type(name3))
# Out:
# Suresh
# <class 'str'>

# %% [markdown]
# ## Multiline String:

# %%
text='My name is Smruti \
I am from Pune \
I am Fresher'

print(text)
# Out:
# My name is Smruti I am from Pune I am Fresher

# %%
text='''My Name is Smruti
I am from Pune
I am Fresher'''

print(text)
# Out:
# My Name is Smruti
# I am from Pune
# I am Fresher

# %%
intro=""" My Name is Smruti
I am from Pune"""

print(intro)
# Out:
#  My Name is Smruti
# I am from Pune

# %% [markdown]
# ## Handling Escape character:

# %%
str6="let's play cricket"
print(str6)
# Out:
# let's play cricket

# %%
str6='let\'s play cricket'
print(str6)
# Out:
# let's play cricket

# %% [markdown]
# ## Indexing: Positive Indexing
# ##### individual element print krayche astil tr indexing use krtat. It starts from 0.

# %%
str="Jay Ganesh"

print(str)
# Out:
# Jay Ganesh

# %%
print(str1[0])
print(str1[1])
print(str1[2])
print(str1[3])
print(str1[4])
print(str1[5])
print(str1[6])
# Out:
# J
# a
# y
#
# G
# a
# n

# %% [markdown]
# ## Negative Indexing:
# ##### It starts from -1.

# %%
str1="Jay Ganesh"

print(str1[-10])
print(str1[-9])
print(str1[-8])
# Out:
# J
# a
# y

# %% [markdown]
# #### String Slicing:-- [Start:Stop:Step]

# %%
str1="Jay Ganesh"
print(str1[4:10])
# Out:
# Ganesh

# %%
str2="Welcome to India" 
print(str2[11:16])
# Out:
# India

# %%
str3="Welcome to India" 
print(str3[0:7])
# Out:
# Welcome

# %%
str3="Welcome to India" 
print(str3[:7])
# Out:
# Welcome

# %%
str3="Welcome to India" 
print(str3[:])
# Out:
# Welcome to India

# %% [markdown]
# #### Step Indexing:-- kiti element skip krayche ahet

# %%
str3="Welcome to India" 
print(str3[0:7:1])
# Out:
# Welcome

# %%
str4="Welcome to India" 
print(str4[0:12:2])
# Out:
# Wloet

# %%
str1="Jay Ganesh"
print(str1[4:10:2])
# Out:
# Gns

# %%
str1="Jay Ganesh"
print(str1[0:2])
# Out:
# Ja

# %% [markdown]
# #### String is Immutability:-- string ekda create zali ki tyamdhe change hot nahi

# %%
greeting="Hello World"
print(greeting)
# Out:
# Hello World

# %% [markdown]
# #### String Concatenation:-- minimum don kiwa tyapeksha jast string join krnysathi

# %%
greeting="Hello" 
name="World"
space=" "
message=greeting+space+name
print(message)
# Out:
# Hello World

# %%
greeting="Hello" 
name="World"
space=" "
message=greeting+space+name
print(message,message,message)
# Out:
# Hello World Hello World Hello World

# %% [markdown]
# #### String Repitition(*)Asterisk Operator:-- multiple time ekhadya string la repeat krayche asel tr

# %%
greeting="Hello" 
name="World"
message=greeting+name+space
message=message+" "
print(message*50)
# Out:
# HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld  HelloWorld
