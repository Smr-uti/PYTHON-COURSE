# %% [markdown]
# ## Arthmatic Opertors
# 1.Addition (+)

# %%
a=10
print(a)
print(id(a))
# Out:
# 10
# 140720426550680

# %%
b=5
print(b)
print(id(b))
# Out:
# 5
# 140720426550520

# %%
c=a+b   
print(id(c))

print(c)
# Out:
# 140720426550840
# 15

# %% [markdown]
# #### 2. Substraction

# %%
p=10
q=5
r=p-q

print(r)
# Out:
# 5

# %% [markdown]
# #### 3. Multiplication

# %%
x=10
y=2
z=x*y
print(z)
# Out:
# 20

# %% [markdown]
# #### 4. Division

# %%
a=10
b=5
c=a/b
print(c)
# Out:
# 2.0

# %% [markdown]
# #### 5. Floor Vision

# %%
a=10
b=5
c=a//b
print(c)
# Out:
# 2

# %% [markdown]
# #### 6. Modulus

# %%
a=10
b=3
c=a%b

print(c)
# Out:
# 1

# %% [markdown]
# #### 7.Exponential (**) ->Raise to power

# %%
a=2
b=3
c=a**b
print(c)
# Out:
# 8

# %% [markdown]
# #### 8.Comments in Python

# %%
#d=10  
b=5   # 5 is stored in b
c=a+b  #c is addition of a and b
#print(d)

# %% [markdown]
# #### 9.Precedence in Python

# %%
result=(2+3)*4
print(result)

result=2+3**2
print(result)

result=10-2+3
print(result)
# Out:
# 20
# 11
# 11

# %% [markdown]
# #### Type conversions

# %%
a=3.8
result=int(a)
print(result)

# %%
print(type(a))

# %%
print(type(result))

# %% [markdown]
# #### String to Integer

# %%
b="100"
print(type(b))

# %%
result=int(b)
print(result)

# %%
print(type(result))

# %% [markdown]
# #### Boolean to Integer

# %%
a=False
print(type(a))

# %%
result=int(a)

# %%
print(result)

# %%
print(type(result))

# %%
a=10
b=5
c=a/b
print(c)
# Out:
# 2.0
