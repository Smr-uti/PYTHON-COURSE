# %%
msg= "Hello World"
msg1="Hello India"
fobj=open("text2.txt", "w")
fobj.write(msg)
fobj.close()
fobj2=open("text2.txt", "w")
fobj.write(msg1)
fobj.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 7
#       3 fobj=open("text2.txt", "w")
#       4 fobj.write(msg)
#       5 fobj.close()
#       6 fobj2=open("text2.txt", "w")
# ----> 7 fobj.write(msg1)
#       8 fobj.close()
#
# ValueError: I/O operation on closed file.
