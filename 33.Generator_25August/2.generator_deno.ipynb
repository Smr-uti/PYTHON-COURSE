# %%
def generator_demo():
    yield "first statement"
    yield "second statement"
    yield "third statement"

gen=generator_demo()

# %%
gen=generator_demo()

# %%
for i in gen:
    print(i)
# Out:
# first statement
# second statement
# third statement

# %%
def generator_demo():
    yield "first statement"
    yield "second statement"
    yield "third statement"

# %%
gen1=generator_demo()
print(next(gen1))
