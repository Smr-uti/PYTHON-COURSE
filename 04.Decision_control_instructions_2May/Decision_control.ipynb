# %% [markdown]
# ## Decision Control Instructions:

# %% [markdown]
# #### 1.If Statement:-- Single condition sathi

# %%
print("statement1")
print("statement2")
print("statement3")
# Out:
# statement1
# statement2
# statement3

# %%
a=10

if a>18:

    print("statement1")
    print("statement2")
    print("statement3")


age=int(input("Enter Your Age:"))

print(age)
# Out:
# 20

# %%
age=int(input("Enter Your Age:"))

print(age)
if (age>=18):
    print("You are eligible for voting")
    print("please go for voting!")

print("Program execution completed")
# Out:
# 40
# You are eligible for voting
# please go for voting!
# Program execution completed

# %% [markdown]
# #### 2.If else Statement:--2 Condition sathi

# %%
age=int(input("Enter your age:"))
print(age)

if (age>=18):
    print("You are eleigible for voting")
else:
    print("You are not eligible for voting:")

print("Program execution completed")
# Out:
# 20
# You are eleigible for voting
# Program execution completed

# %% [markdown]
# #### 3.If-elif-else Statement:-- Multiple condition sathi if-elif-else

# %%
age=int(input("Enter Your Age:"))
print(age)

if(age<13):
    print("Child")
elif(age<18):
    print("Teenager")
else:
    print("Adult")

print("Program Execution Completed")
# Out:
# 12
# Child
# Program Execution Completed

# %% [markdown]
# ## Logical operatoor: and

# %%
age= int(input("Enter your age:"))
nationality=input("Enter your nationality:")
print(age)
print(nationality)

if (age>=18) and (nationality=="indian"):
    print("You are eligible for voting")

print("Program executed sucessfully")
# Out:
# 15
# indian
# Program executed sucessfully

# %% [markdown]
# ## Logical operatoor: or

# %%
age= int(input("Enter your age:"))
nationality=input("Enter your nationality:")
print(age)
print(nationality)

if (age>=18) or (nationality=="indian"):
    print("You are eligible for voting")

print("Program executed sucessfully")
# Out:
# 13
# african
# Program executed sucessfully

# %%
age= int(input("Enter your age:"))
nationality=input("Enter your nationality:")
print(age)
print(nationality)

if (age>=18) or (nationality=="indian"):
    print("You are eligible for voting")
else:
    print("You are eligible for voting")

print("Program executed sucessfully")
# Out:
# 10
# American
# You are eligible for voting
# Program executed sucessfully
