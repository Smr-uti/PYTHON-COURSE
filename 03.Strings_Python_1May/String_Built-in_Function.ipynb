# %% [markdown]
# ## Built-in Function:

# %% [markdown]
# #### 1.len():-- string mdhe kiti character ahet te output dete

# %%
name="Rahul"
print(len(name))
# Out:
# 5

# %%
greeting="Hello World"
print(len(greeting))
# Out:
# 11

# %% [markdown]
# #### 2.min():-- sglyat smallest character. A to Z mdhe (A-smallest, Z-highest)

# %%
name="Rahul"
name1="PrOgramMing"

print(min(name))
print(min(name1))
# Out:
# R
# M

# %% [markdown]
# #### 3.max():-- sglyat highest value character print krte.
# ##### ASCII Code values nusar

# %%
name3="MaheSh"
print(max(name3))
# Out:
# h

# %% [markdown]
# #### 4. str():-- It converts int, float or complex into string.

# %%
a=10
b=10.1
c=10+4j

print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
a1=str(a)
b1=str(b)
c1=str(c)   

print(type(a1))
print(type(b1))
print(type(c1))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# #### 5. chr():-- It returns character from unicode values. Unicode values wrun character return dete.

# %%
char=chr(75)
print(char)
# Out:
# K

# %% [markdown]
# #### 6. ord():-- It returns unicode value of character. Character chi unicode value dete.

# %%
unicode=ord("W")
print(unicode)
# Out:
# 87
